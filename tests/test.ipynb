# %%
import os
import sys

sys.path.append(os.path.abspath('..'))  # Adds the parent directory to sys.path

from src.aivene import Aivene

# %%
aivene = Aivene(api_key='zpka_b0835ecce48346fcad188c5acb059a52_15fa952f')

# %%
response = aivene.generate_queries(
    user_input='I want to see a movie with Tom Cruise',
)

# %%
response = aivene.search(
    query='I want to see a movie with Tom Cruise',
)

# %%
response = aivene.search_from_input(
    user_input='I want to see a movie with Tom Cruise',
)

# %%
response.json()
# Out:
# {'prompt': {'user_content': 'I want to see a movie with Tom Cruise',
#   'n_queries': 1},
#  'queries': 'movies starring Tom Cruise',
#  'search_results': [{'title': 'Movies starring Tom Cruise',
#    'description': 'Collateral is a classic example of how casting against type can sometimes result in a remarkable success. Here we have Tom Cruise, who has spent the majority of\xa0...',
#    'url': 'https://www.reelviews.net/search/actor/tom-cruise'},
#   {'title': 'Tom Cruise: Movies, TV, and Bio',
#    'description': 'Top titles · Top Gun · The Last Samurai (2003) · Jerry Maguire (4K UHD) · Mission: Impossible II · Top Gun: Maverick · Magnolia · Rain Man · Edge of Tomorrow.',
#    'url': 'https://www.amazon.com/prime-video/actor/Tom-Cruise/amzn1.dv.gti.24fc4c88-f6b9-47e8-9ed5-343ef76e7505/'},
#   {'title': 'Movies and TV shows starring Tom Cruise',
# ...
