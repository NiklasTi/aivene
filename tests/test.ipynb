# %%
import os
import sys

sys.path.append(os.path.abspath('..'))  # Adds the parent directory to sys.path

from src.aivene import Aivene

# %%
client = Aivene(api_key='zpka_0a6075c5e2f74e66aa289c54708cfbe8_50b67016')

# %%
keyword = "machine learning"
# Additional parameters are optional and can be adjusted as needed

try:
    response = client.search(keyword=keyword)
    print(response.json())
except Exception as e:
    print(e)
# Out:
# {'data': [{'title': 'Machine learning', 'description': 'Machine learning (ML) is a field of study in artificial intelligence concerned with the development and study of statistical algorithms that can learn from\xa0...', 'url': 'https://en.wikipedia.org/wiki/Machine_learning'}, {'title': 'What Is Machine Learning (ML)?', 'description': 'Machine learning (ML) is a branch of AI and computer science that focuses on the using data and algorithms to enable AI to imitate the way that humans\xa0...', 'url': 'https://www.ibm.com/topics/machine-learning'}, {'title': 'Machine learning, explained', 'description': 'Machine learning is a subfield of artificial intelligence that gives computers the ability to learn without explicitly being programmed. “In\xa0...', 'url': 'https://mitsloan.mit.edu/ideas-made-to-matter/machine-learning-explained'}, {'title': 'What is Machine Learning? Definition, Types, Tools & More', 'description': 'Machine learning is a subset of AI, which uses algorithms that learn from data to make predictions. These predictions can be generated through supervised\xa0...', 'url': 'https://www.datacamp.com/blog/what-is-machine-learning'}, {'title': 'Machine Learning Tutorial', 'description': 'This machine learning tutorial helps you gain a solid introduction to the fundamentals of machine learning and explore a wide range of\xa0...', 'url': 'https://www.geeksforgeeks.org/machine-learning/'}, {'title': 'Supervised Machine Learning: Regression and Classification', 'description': 'Build and train supervised machine learning models for prediction and binary classification tasks, including linear regression and logistic regression The\xa0...', 'url': 'https://www.coursera.org/learn/machine-learning'}, {'title': "Google's Machine Learning Crash Course", 'description': "Google's fast-paced, practical introduction to machine learning, featuring a series of lessons with video lectures, real-world case studies, and hands-on\xa0...", 'url': 'https://developers.google.com/machine-learning/crash-course'}, {'title': 'What Is Machine Learning? Definition, Types, and Examples', 'description': 'Machine learning refers to the general use of algorithms and data to create autonomous or semi-autonomous machines. Deep learning, meanwhile, is\xa0...', 'url': 'https://www.coursera.org/articles/what-is-machine-learning'}, {'title': 'What Is Machine Learning: Definition and Examples', 'description': 'Machine learning gives systems the ability to analyze data and make predictions on their own, resembling human ways of learning.', 'url': 'https://builtin.com/machine-learning'}, {'title': 'Machine Learning and Artificial Intelligence', 'description': 'AWS offers the broadest and deepest set of artificial intelligence (AI) and machine learning (ML) services and supporting cloud infrastructure.', 'url': 'https://aws.amazon.com/machine-learning/'}, {'title': 'What Is Machine Learning and How Does It Work?', 'description': 'Mar 27, 2024', 'url': 'https://www.simplilearn.com/tutorials/machine-learning-tutorial/what-is-machine-learning'}, {'title': 'Machine Learning Applications in Non-Conventional Machining ...', 'description': '... five years. 3. 4. 5. McKinsey predicts machine learning will reduce supply chain 197 Analysis of Non-Traditional Machining Processes Using Machine Learning.', 'url': 'https://books.google.com/books?id=cN8XEAAAQBAJ&pg=PA197&lpg=PA197&dq=machine+learning&source=bl&ots=8zD4gdDOuS&sig=ACfU3U3Ewe_yIWkUHLZb-qMTR4DqFUh6tA&hl=en&sa=X&ved=2ahUKEwi90qi9-KiFAxUayTgGHUMVB3oQ6AF6BQi2ARAD'}, {'title': 'Embedded Machine Learning for Cyber-Physical, IoT, and Edge ...', 'description': '... -39932-9_7 175 systems widely available to machine learning researchers and data scientists. Machine Learning for Heterogeneous Manycore Design 1 Introduction.', 'url': 'https://books.google.com/books?id=dRzcEAAAQBAJ&pg=PA174&lpg=PA174&dq=machine+learning&source=bl&ots=3W3QcdIaiw&sig=ACfU3U3tExkQ0l6gKcCUDPNJTj9-RSLCMA&hl=en&sa=X&ved=2ahUKEwi90qi9-KiFAxUayTgGH ...

# %%
user_input = "I am looking for a search engine to use with my AI"
n_queries = 5 # Optional: Number of queries to generate

try:
    response = client.generate_queries(user_input, n_queries)
    print(response.json())
except Exception as e:
    print(e)
# Out:
# {'prompt': '{"user_content":"I am looking for a search engine to use with my AI","n_queries":5}', 'queries': ['Best search engines for AI integration', 'Search engines compatible with AI technology', 'AI-optimized search engines', 'Search engines for artificial intelligence use', 'Comparisons of search engines for AI systems']}

# %%
user_input = "I am looking for a search engine to use with my AI"
n_queries = 1 # Optional: Number of queries to generate

try:
    response = client.search_queries(user_input, n_queries)
    print(response.json())
except Exception as e:
    print(e)
# Out:
# {'prompt': '{"user_content":"I am looking for a search engine to use with my AI","n_queries":1}', 'queries': 'search engine for artificial intelligence integration', 'search_results': [{'title': 'What is AI-powered site search?', 'description': 'With AI-powered search, the platform learns from data on users to automatically generate the most accurate and relevant search experiences. This\xa0...', 'url': 'https://www.algolia.com/blog/ai/what-is-ai-powered-site-search/'}, {'title': '10 Best AI Search Engines To Try in 2024', 'description': 'AI Search Engines are the type of search engine platforms that mainly use machine learning models and AI to deliver the results or solutions\xa0...', 'url': 'https://www.geeksforgeeks.org/ai-search-engines/'}, {'title': 'Can This A.I.-Powered Search Engine Replace Google? ...', 'description': '... search engine built from scratch with artificial intelligence ... artificial intelligence. Share ... integration with Google Maps. But Perplexity\xa0...', 'url': 'https://www.nytimes.com/2024/02/01/technology/perplexity-search-ai-google.html'}, {'title': 'AI-Powered Search Engine', 'description': 'Lucidworks Fusion Search Platform with Lucidworks AI now includes integration capabilities for all generative AI and large language models (LLMs). Recent Gen AI ...', 'url': 'https://lucidworks.com/ai-powered-search/'}, {'title': 'The 8 AI Search Engines That You Should Replace Google ...', 'description': 'Although Google has been the dominant search engine for a long time, the emergence of artificial intelligence (AI) has paved the way for\xa0...', 'url': 'https://www.kdnuggets.com/top-8-ai-search-engine-that-you-should-replace-with-google'}, {'title': 'Top 10 AI Search Engines in 2024', 'description': "Top 10 AI Search Engines of 2024. Microsoft Bing. Microsoft Bing, integrating OpenAI's GPT-4, exemplifies innovation in the AI search engine ...", 'url': 'https://www.blockchain-council.org/ai/top-10-ai-search-engines/'}, {'title': 'AI in Search Engines: Everything You Need to Know', 'description': 'The biggest way search engines use AI is to rank webpages, videos, and other content in search results. Google (and other search engines) rely\xa0...', 'url': 'https://www.marketingaiinstitute.com/blog/how-search-engines-use-artificial-intelligence'}, {'title': 'The 10 best AI search engines to try', 'description': 'An AI search engine can effectively improve traditional search engines by using AI and machine learning. This technology reached the\xa0...', 'url': 'https://nordvpn.com/blog/ai-search-engines/'}, {'title': '7 Best AI Search Engines in 2024 (Free & Paid)', 'description': 'Best AI Search Engines · Microsoft Copilot (formerly Bing Chat) · Google Gemini (formerly Bard) · ChatGPT · You.com · Perplexity · Aria by Opera · Phind\xa0...', 'url': 'https://usefulai.com/tools/ai-search-engines'}, {'title': '7 Best AI Search Engines to Use as Google Alternatives', 'description': "Perplexity AI is a cutting-edge search engine tool that utilizes sophisticated artificial intelligence technologies, including OpenAI's GPT-3\xa0...", 'url': 'https://geekflare.com/best-ai-search-engines/'}, {'title': 'What are the top AI search engines that are free to use?', 'description': 'Some of the top free AI search engines include Google AI Search, which integrates AI algorithms to provide more relevant search results; Bing,\xa0...', 'url': 'https://www.linkedin.com/advice/3/what-top-ai-search-engines-free-use-skills-artificial-intelligence-iefhf'}, {'title': 'AI in Search Engines: The Future of Finding Information', 'description': "What roles do AI play in search engines? A question we never thought we'd look forward to. But with the advances in artificial intelligence ...", 'url': 'https://binmile.com/blog/role-of-ai-in-future-of-search-engines/'}, {'title': 'Generative AI In Search: An Overview Of ...', 'description': 'Microsoft Bing is also using artificial intelligence to help improve the search experience. Their AI is int ...

# %%
response
# Out:
# <Response [200]>

# %%
import requests

url = "https://aivene-main-72f6e2d.d2.zuplo.dev/search"
# headers = {
#     "Authorization": "Bearer zpka_0a6075c5e2f74e66aa289c54708cfbe8_50b67016"
# }
headers = {
    'Authorization': f"Bearer zpka_0a6075c5e2f74e66aa289c54708cfbe8_50b67016",
# 'Api-Key': self.api_key,
}

payload = {
    "keyword": "machine learning"
}

response = requests.post(url, headers=headers, json=payload)
print(response.json())
# Out:
# {'data': [{'title': 'Machine learning', 'description': 'Machine learning (ML) is a field of study in artificial intelligence concerned with the development and study of statistical algorithms that can learn from\xa0...', 'url': 'https://en.wikipedia.org/wiki/Machine_learning'}, {'title': 'What Is Machine Learning (ML)?', 'description': 'Machine learning (ML) is a branch of AI and computer science that focuses on the using data and algorithms to enable AI to imitate the way that humans\xa0...', 'url': 'https://www.ibm.com/topics/machine-learning'}, {'title': 'Machine learning, explained', 'description': 'Machine learning is a subfield of artificial intelligence that gives computers the ability to learn without explicitly being programmed. “In\xa0...', 'url': 'https://mitsloan.mit.edu/ideas-made-to-matter/machine-learning-explained'}, {'title': 'What is Machine Learning? Definition, Types, Tools & More', 'description': 'Machine learning is a subset of AI, which uses algorithms that learn from data to make predictions. These predictions can be generated through supervised\xa0...', 'url': 'https://www.datacamp.com/blog/what-is-machine-learning'}, {'title': 'Machine Learning Tutorial', 'description': 'This machine learning tutorial helps you gain a solid introduction to the fundamentals of machine learning and explore a wide range of\xa0...', 'url': 'https://www.geeksforgeeks.org/machine-learning/'}, {'title': 'What Is Machine Learning? Definition, Types, and Examples', 'description': 'Machine learning refers to the general use of algorithms and data to create autonomous or semi-autonomous machines. Deep learning, meanwhile, is\xa0...', 'url': 'https://www.coursera.org/articles/what-is-machine-learning'}, {'title': "Google's Machine Learning Crash Course", 'description': "Google's fast-paced, practical introduction to machine learning, featuring a series of lessons with video lectures, real-world case studies, and hands-on\xa0...", 'url': 'https://developers.google.com/machine-learning/crash-course'}, {'title': 'Supervised Machine Learning: Regression and Classification', 'description': 'Build and train supervised machine learning models for prediction and binary classification tasks, including linear regression and logistic regression The\xa0...', 'url': 'https://www.coursera.org/learn/machine-learning'}, {'title': 'What Is Machine Learning: Definition and Examples', 'description': 'Machine learning gives systems the ability to analyze data and make predictions on their own, resembling human ways of learning.', 'url': 'https://builtin.com/machine-learning'}, {'title': 'Machine Learning for Business: Using Amazon SageMaker and ...', 'description': "... machine learning application, what you're doing is showing a bunch of ... Machine learning problems can be broken down into two types: Supervised machine\xa0...", 'url': 'https://books.google.com/books?id=GDszEAAAQBAJ&pg=PP46&lpg=PP46&dq=machine+learning&source=bl&ots=-HKWwIu6ZP&sig=ACfU3U0Cp-r4WMzBNtltx4vFLFyr0Jw9Zg&hl=en&sa=X&ved=2ahUKEwjegv2i8aiFAxXGTGwGHYUWCjMQ6AF6BQiuARAD'}, {'title': 'Machine Learning - Page 55 - Google Books Result', 'description': 'GUNRATHI BHARATHKUMAR GOUD. Applications. of. Machine. Learning. Machine learning algorithms are used in circumstances where the solution is required to\xa0...', 'url': 'https://books.google.com/books?id=pevtEAAAQBAJ&pg=PA55&lpg=PA55&dq=machine+learning&source=bl&ots=8KPZN4MTsx&sig=ACfU3U1K1nLUmIkYIcQEPxLuRxe5i1XNhA&hl=en&sa=X&ved=2ahUKEwjegv2i8aiFAxXGTGwGHYUWCjMQ6AF6BQioARAD'}, {'title': 'Statistics for Machine Learning - Page 11 - Google Books Result', 'description': '... machine learning algorithms need to be trained on two datasets, called training ... Machine Learning Steps in machine learning model development and deployment.', 'url': 'https://books.google.com/books?id=C-dDDwAAQBAJ&pg=PA11&lpg=PA11&dq=machine+learning&source=bl&ots=j33t-rq32x&sig=ACfU3U2gAnv6qxCypY0ofKePjhsBiWu9OQ&hl=en&sa=X&ved=2ahUKEwjegv2i8aiFAxXGTGwGHYUWC ...
